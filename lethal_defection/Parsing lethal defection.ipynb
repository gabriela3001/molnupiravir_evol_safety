# %%
import os
import pickle
import pandas as pd
import numpy as np
from itertools import combinations
import matplotlib.pyplot as plt
from numpy import nan

# %%
files = [x for x in os.listdir('lethal_defection/') if 'results' in x]

# %%
all_results = []
for file in files:
    with open('lethal_defection/'+file, 'rb') as f:
        result_file = pickle.load(f)
        for r in result_file['results']:
            all_results.append(r)
            
result_df = pd.DataFrame(all_results)

# %%
with open('lethal_defection/paramgrid_newparams_a03.txt','rb') as f:
    param_grid = pickle.load(f)

# %%
along_m = sorted(list(set(result_df['m'])))
along_n = sorted(list(set(result_df['n'])))
along_ap = sorted(list(set(result_df['ap'])))
along_ttr = sorted(list(set(result_df['ttr'])))
along_qd = sorted(list(set(result_df['qd'])))
along_m.remove(20000)
along_ap.remove(7.8)
along_ttr.remove(5)
along_qd.remove(1-3e-6)
along_n.remove(87)
all_along_params = [('m',along_m), ('n',along_n), ('ap',along_ap), ('ttr',along_ttr), ('qd',along_qd)]
all_names_params = ['m', 'n', 'ap', 'ttr', 'qd']

# %%
all_colormap_params = list(combinations(all_along_params, 2))
all_colormap_names = list(combinations(all_names_params,2))

# %%
result_file
# Out:
# {'param': 999,
#  'results': [{'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 0.0,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 0.7368421052631579,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 1.4736842105263157,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 2.2105263157894735,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 2.9473684210526314,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 3.6842105263157894,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 4.421052631578947,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 5.157894736842105,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 5.894736842105263,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 6.63157894736842,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 7.368421052631579,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 8.105263157894736,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 8.842105263157894,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 9.578947368421051,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 10.31578947368421,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 11.052631578947368,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 11.789473684210526,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 12.526315789473683,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 13.26315789473684,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 14.0,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.999999,
#    'ttr': 5,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059608815.2061456},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 0.0,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1093132705.72283},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 0.7368421052631579,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1089347428.8225398},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 1.4736842105263157,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1085458631.1504061},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 2.2105263157894735,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1081470249.794653},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 2.9473684210526314,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1077381147.4904137},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 3.6842105263157894,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1073190524.7679082},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 4.421052631578947,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1068906726.8777124},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 5.157894736842105,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1064768143.8448355},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 5.894736842105263,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1061648472.178402},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 6.63157894736842,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1059502914.1877298},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 7.368421052631579,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1058078476.3276479},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 8.105263157894736,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1057182335.8422359},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 8.842105263157894,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1056668185.3230554},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 9.578947368421051,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1056425901.0626014},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 10.31578947368421,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1056372280.912345},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 11.052631578947368,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1056446366.711514},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 11.789473684210526,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1056602938.388167},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 12.526315789473683,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1056809101.8334075},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 13.26315789473684,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1057041278.2821983},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 14.0,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1057282893.2355628},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999988711621083,
#    'ttr': 5,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1065588387.3165463},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 0.0,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1117092142.2191272},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 0.7368421052631579,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1111165849.8303688},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 1.4736842105263157,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1104839301.134604},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 2.2105263157894735,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1098110351.513683},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 2.9473684210526314,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1090968891.4697073},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 3.6842105263157894,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1083405349.8589158},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 4.421052631578947,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1075429510.5463822},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 5.157894736842105,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1067542476.2867665},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 5.894736842105263,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1061624855.9146667},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 6.63157894736842,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1057617849.2290578},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 7.368421052631579,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1055018412.6166179},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 8.105263157894736,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1053444038.2162613},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 8.842105263157894,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1052605262.6471056},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 9.578947368421051,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1052284694.8387674},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 10.31578947368421,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1052319271.9804316},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 11.052631578947368,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 1052589525.8769162},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0,
#    'ap': 7.815789473684211,
#    'qd': 0.9999987257250142,
#    'ttr': 11.789473684210526,
#    'Y_control': 1059608815.2061456,
#    'Y_treatment': 

#    'Y_control': 2759372.375256079,
#    'Y_treatment': 2694722.7712864364},
#   {'m': 8973.684210526317,
#    'n': 631.9473684210527,
#    'd': 0.001,
#    'ap': 7.815789473684211,
#    'qd': 0.9999981670192891,
#    'ttr': 8.842105263157894,
#    'Y_control': 2759372.375256079,
#    'Y_treatment': 2710533.7374895536},
#   ...]}

# %%
dict_other_vals = {'m':20000, 'n':87, 'ap': 7.8, 'qd':1-3e-6, 'ttr':5}

# %%
result_df_control = result_df[result_df['d'] == 0]
result_df_lethdef_2 = result_df[result_df['d'] == 0.01]
result_df_lethdef_3 = result_df[result_df['d'] == 0.001]

# %%
all_matrices_for_cmap_control = []

for comb in all_colormap_params:
    params_axes = (comb[0][0], comb[1][0])
    print(params_axes)
    other_params = set(all_names_params)-set(params_axes)

    colormap_params = np.zeros((len(comb[0][1]), len(comb[1][1])))
    
    for xind in range(len(comb[0][1])):
        for yind in range(len(comb[0][1])):
            df_axes = result_df_control.copy()
            for p in other_params:
                df_axes = df_axes[df_axes[p] == dict_other_vals[p]]
            df_axes = df_axes[(df_axes[params_axes[0]] == comb[0][1][xind])&(df_axes[params_axes[1]] == comb[1][1][yind])]
            colormap_params[xind, yind] = list(df_axes['Y_treatment'])[0]/list(df_axes['Y_control'])[0]
            
    all_matrices_for_cmap_control.append(colormap_params)
# Out:
# ('m', 'n')
# ('m', 'ap')
# ('m', 'ttr')
# ('m', 'qd')
# ('n', 'ap')
# ('n', 'ttr')
# ('n', 'qd')
# ('ap', 'ttr')
# ('ap', 'qd')
# ('ttr', 'qd')

# %%
all_matrices_for_cmap_lethdef_2 = []

for comb in all_colormap_params:
    params_axes = (comb[0][0], comb[1][0])
    print(params_axes)
    other_params = set(all_names_params)-set(params_axes)

    colormap_params = np.zeros((len(comb[0][1]), len(comb[1][1])))
    
    for xind in range(len(comb[0][1])):
        for yind in range(len(comb[0][1])):
            df_axes = result_df_lethdef_2.copy()
            for p in other_params:
                df_axes = df_axes[df_axes[p] == dict_other_vals[p]]
            df_axes = df_axes[(df_axes[params_axes[0]] == comb[0][1][xind])&(df_axes[params_axes[1]] == comb[1][1][yind])]
            colormap_params[xind, yind] = list(df_axes['Y_treatment'])[0]/list(df_axes['Y_control'])[0]
            
    all_matrices_for_cmap_lethdef_2.append(colormap_params)
# Out:
# ('m', 'n')
# ('m', 'ap')
# ('m', 'ttr')
# ('m', 'qd')
# ('n', 'ap')
# ('n', 'ttr')
# ('n', 'qd')
# ('ap', 'ttr')
# ('ap', 'qd')
# ('ttr', 'qd')

# %%
all_matrices_for_cmap_lethdef_3 = []

for comb in all_colormap_params:
    params_axes = (comb[0][0], comb[1][0])
    print(params_axes)
    other_params = set(all_names_params)-set(params_axes)

    colormap_params = np.zeros((len(comb[0][1]), len(comb[1][1])))
    
    for xind in range(len(comb[0][1])):
        for yind in range(len(comb[0][1])):
            df_axes = result_df_lethdef_3.copy()
            for p in other_params:
                df_axes = df_axes[df_axes[p] == dict_other_vals[p]]
            df_axes = df_axes[(df_axes[params_axes[0]] == comb[0][1][xind])&(df_axes[params_axes[1]] == comb[1][1][yind])]
            colormap_params[xind, yind] = list(df_axes['Y_treatment'])[0]/list(df_axes['Y_control'])[0]
            
    all_matrices_for_cmap_lethdef_3.append(colormap_params)
# Out:
# ('m', 'n')
# ('m', 'ap')
# ('m', 'ttr')
# ('m', 'qd')
# ('n', 'ap')
# ('n', 'ttr')
# ('n', 'qd')
# ('ap', 'ttr')
# ('ap', 'qd')
# ('ttr', 'qd')

# %%
indices_colormaps = []
for i in range(5):
    for j in range(2):
        indices_colormaps.append((i,j))
indices_colormaps = dict(zip(range(10), indices_colormaps))

# %%
def calculate_ticks(ticklabels, truerange, tickrange):
    tick_pos = []
    for l in ticklabels:
        NewValue = (((l - truerange[0]) * (tickrange[1] - tickrange[0])) / (truerange[1] - truerange[0])) + tickrange[0]
        tick_pos.append(NewValue)
    return(np.array(tick_pos))

def calculate_ticks_log(ticklabels, truerange, tickrange):
    tick_labels = np.log(ticklabels)
    true_range = np.log(truerange)
    tick_pos = []
    for l in ticklabels:
        NewValue = (((l - truerange[0]) * (tickrange[1] - tickrange[0])) / (truerange[1] - truerange[0])) + tickrange[0]
        tick_pos.append(NewValue)
    return(np.array(tick_pos))

# %%
param_ticks = {'m':[1500,5000,10000,15000,20000,25000,29900],
               'n':[1,200,400,600,800,1000],
               'ap':[7.7,8.0,8.3,8.6,8.8],
               'qd':[1-1e-6,1-3e-6,1-5e-6,1-7.5e-6,1-1e-5], 
               'ttr':[0,3,7,10,14]}
param_ranges = {'m':[1500,29900],
                'n':[1,1000],
                'ap':[7.7,8.8],
                'qd':[1e-6,1e-5],
                'ttr':[0,14]}

# %%
all_xticks, all_yticks = [],[]
all_xticklabels, all_yticklabels = [],[]

for i in range(10):
    
    x_param, y_param = all_colormap_names[i]

    if y_param == 'qd':
        ticks_y = calculate_ticks_log(1-np.array(param_ticks[y_param]), param_ranges[y_param], [0,19])
    else:
        ticks_y = calculate_ticks(np.array(param_ticks[y_param]), param_ranges[y_param], [0,19])
        
    if y_param == 'qd':
        labels_y = list(["{:.1e}".format(1-x) for x in np.array(param_ticks[y_param])])
    elif y_param == 'ap':
        labels_y = [np.round(x,2) for x in param_ticks[y_param]]
    else:
        labels_y = [int(np.round(x)) for x in param_ticks[y_param]]
        
    if x_param == 'qd': 
        ticks_x = 19-np.array(calculate_ticks_log(1-np.array(param_ticks[x_param]), param_ranges[x_param], [0,19])[::-1])
    else:
        ticks_x = 19-np.array(calculate_ticks(np.array(param_ticks[x_param]), param_ranges[x_param], [0,19])[::-1])
            

    if x_param == 'qd':
        labels_x = list(["{:.1e}".format(1-x) for x in np.array(param_ticks[x_param])])
    elif x_param == 'ap':
        labels_x = [np.round(x,2) for x in param_ticks[x_param]]
    else:
        labels_x = [int(np.round(x)) for x in param_ticks[x_param]]
    
    
    all_xticks.append(ticks_x)
    all_yticks.append(ticks_y)
    all_xticklabels.append(labels_x)
    all_yticklabels.append(labels_y)

# %%
params_description = {'m':'Number of lethal positions $m$',
                      'n':'Number of gain-of-function positions $n$',
                      'ap': 'Clearance rate in clearance phase $a_1$ (per day)',
                      'qd': 'Viral mutation rate under treatment $u_1$ (per bp)',
                      'ttr': 'Time of start of treatment (day)'}

# %%
fig, ax = plt.subplots(5,2,figsize=(8,18))

for i in range(10):
    im = ax[indices_colormaps[i]].imshow(all_matrices_for_cmap_control[i][::-1], cmap = 'seismic', vmin = 0., vmax = 2)
    if all_colormap_params[i][1][0] in ['qd']:
        im = ax[indices_colormaps[i]].imshow(np.flip(all_matrices_for_cmap_control[i][::-1],1), cmap = 'seismic', vmin = 0., vmax = 2)

    ax[indices_colormaps[i]].set_xticks(all_yticks[i])
    ax[indices_colormaps[i]].set_xticklabels(all_yticklabels[i])
    
    ax[indices_colormaps[i]].set_yticks(all_xticks[i])
    ax[indices_colormaps[i]].set_yticklabels(all_xticklabels[i][::-1])    
    
    
    ax[indices_colormaps[i]].set_ylabel(params_description[all_colormap_params[i][0][0]])
    ax[indices_colormaps[i]].set_xlabel(params_description[all_colormap_params[i][1][0]])
    
    
plt.tight_layout(pad=1.0)
plt.savefig('lethal_defection_d0_JAN25.jpg', dpi = 600, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(5,2,figsize=(8,18))

for i in range(10):
    im = ax[indices_colormaps[i]].imshow(all_matrices_for_cmap_lethdef_2[i][::-1], cmap = 'seismic', vmin = 0., vmax = 2)
    if all_colormap_params[i][1][0] in ['qd']:
        im = ax[indices_colormaps[i]].imshow(np.flip(all_matrices_for_cmap_lethdef_2[i][::-1],1), cmap = 'seismic', vmin = 0., vmax = 2)

    ax[indices_colormaps[i]].set_xticks(all_yticks[i])
    ax[indices_colormaps[i]].set_xticklabels(all_yticklabels[i])
    
    ax[indices_colormaps[i]].set_yticks(all_xticks[i])
    ax[indices_colormaps[i]].set_yticklabels(all_xticklabels[i][::-1])    
    
    
    ax[indices_colormaps[i]].set_ylabel(params_description[all_colormap_params[i][0][0]])
    ax[indices_colormaps[i]].set_xlabel(params_description[all_colormap_params[i][1][0]])
    
    
plt.tight_layout(pad=1.0)
plt.savefig('lethal_defection_d001_JAN25.jpg', dpi = 600, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(5,2,figsize=(8,18))

for i in range(10):
    im = ax[indices_colormaps[i]].imshow(all_matrices_for_cmap_lethdef_3[i][::-1], cmap = 'seismic', vmin = 0., vmax = 2)
    if all_colormap_params[i][1][0] in ['qd']:
        im = ax[indices_colormaps[i]].imshow(np.flip(all_matrices_for_cmap_lethdef_3[i][::-1],1), cmap = 'seismic', vmin = 0., vmax = 2)

    ax[indices_colormaps[i]].set_xticks(all_yticks[i])
    ax[indices_colormaps[i]].set_xticklabels(all_yticklabels[i])
    
    ax[indices_colormaps[i]].set_yticks(all_xticks[i])
    ax[indices_colormaps[i]].set_yticklabels(all_xticklabels[i][::-1])    
    
    
    ax[indices_colormaps[i]].set_ylabel(params_description[all_colormap_params[i][0][0]])
    ax[indices_colormaps[i]].set_xlabel(params_description[all_colormap_params[i][1][0]])
    
    
plt.tight_layout(pad=1.0)
plt.savefig('lethal_defection_d0001_JAN25.jpg', dpi = 600, bbox_inches = 'tight')
